# %%
time = input('voce torce para qual time: ')
print('ahhh voce torce para o ' + time)
# Out:
# voce torce para qual time: palmeira
# ahhh voce torce para o palmeira

# %%
nome = input ('qual seu nome: : ')
comida = input ('qual sua comida preferida: ')
print('')
print('bom dia ' + nome +' hoje no almoço vamos servir ' + comida +' esperamos voce goste de ' + comida)
# Out:
# qual seu nome: : claudio
# qual sua comida preferida: lazana
#
# bom dia claudio hoje no almoço vamos servir lazana esperamos voce goste de lazana

# %%
#calculos basicos
#tipos de dados
num1 = 10
num2 = 5
conta =num1 +num2
print(10+5)

#tipos de dados
# String = textos, palavras,,,
# Inteiro = numeros inteiros ex. 10 5 200
# Float = numeros decimais 10.5 2.5 3.6
# Booleanos =Verdadeiros e Falso

#print('2)
#print(2)
# Out:
# 15

# %%
idade =int( input('quantos anos voce tem:'))
nasc = 2024 - idade
print('voce nasceu em ',nasc)
# Out:
# quantos anos voce tem:50
# voce nasceu em  1974

# %%
idade = int(input('quantos anos voce tem: '))
nasc = 2024 - idade
print('voce nasceu em ',nasc )
# Out:
# quantos anos voce tem: 30
# voce nasceu em  1994

# %%
#crie um programa para calcular quantos metros tem um terreno.
#pergunte ao usuario quantos metros tem de largura e comprimento.
#calcule a largura * comprimento
#retorne com a resposta

# %%
largura  = float(input('quantode largura tem o terreno(5.5):'))
comprimento = float(input('quanto de comprimento tem o terreno(20.00): '))
area = largura * comprimento
print ()
print('este terreno tem' ,area , 'metros quadrado')
# Out:
# quantode largura tem o terreno(5.5):8
# quanto de comprimento tem o terreno(20.00): 5
#
# este terreno tem 40.0 metros quadrado

# %%
idade = int(input('quantos anos vc tem: '))
nasc = 2024 -idade
print('voce nasceu ' ,nasc )
# Out:
# quantos anos vc tem: 50
# voce nasceu  1974

# %%
carro = 'astra'
print(carro)
carro = 'silverado'
print(carro)
# Out:
# astra
# silverado

# %%
print([bool(10>5)])
print([bool(10==5)])
print([boo(10>5)])
# Out:
# [True]
# [False]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-de09d956bf12> in <cell line: 3>()
#       1 print([bool(10>5)])
#       2 print([bool(10==5)])
# ----> 3 print([boo(10>5)])
#
# NameError: name 'boo' is not defined

# %%
print([bool(10>5)])
print([bool(10==5)])
print([bool(50>50)])
# Out:
# [True]
# [False]
# [False]

# %%
nota = float(input('qual foi a nota do aluno(0-10): '))
if nota < 3:
  print('lascou...')
elif nota <5:
  print('vai pra conselho...')
elif nota <9:
  print('parabens....')
else:
  print('genio')
# Out:
# qual foi a nota do aluno(0-10): 5
# parabens....

# %% [markdown]
# # crie um programa ,que  calcule a media das nota de
# # trabalho, participação e prova

# %%
trabalho = float(input('qual foi a nota do trabalho '))
participação = float(input('qual foi a nota da participação '))
prova = float(input('qual foi a nota da participação '))
media = trabalho + participação + prova / 3
if nota < 3:
  print('lascou...')
elif nota < 5:
  print('parabens....')
elif nota < 7:
else:
  print(genio)
# Out:
#   File "<ipython-input-26-31381f1fb7fd>", line 10
#     else:
#     ^
# IndentationError: expected an indented block after 'elif' statement on line 9

# %% [markdown]
# # crie

# %%
notaTarabalho = float(input('digie a nota de trabalho: '))
notaProva = float(input('Digite a no da prova: '))
notaPart = float(input('Digite a nota de participação do aluno(a): '))
print('# Seja bem vindo a calculadora de media de nota #')
print()
nomeAluno = input('qual nome do aluno(a): ')
print()
print('Professor(a),digite a nota de trabalho,prova e participação do aluno')
notaTrabalho = float(input('digite a nota do trabalho: '))
notaPova = float(input('digite a nota da prova: '))
notaPart = float(input('digite a nota de participaçao do aluno(a): '))

mediaAluno = round(((notaTrabalho + notaProva +notaPart) / 3),2)


if mediaAluno < 3:
  print(nomeAluno, 'esta reprovado(a) com media', mediaAluno)
elif mediaAluno < 5:
 print(nomeAluno, 'esta em conselho de classe com media', mediaAluno)
elif mediaAluno <10:
  print(nomeAluno, 'esta com media', mediaAluno)
else:
  print(nomeAluno, 'voce foi aprovado(a)com nota mmaxima', mediaAluno)
# Out:
# digie a nota de trabalho: 10
# Digite a no da prova: 10
# Digite a nota de participação do aluno(a): 10
# # Seja bem vindo a calculadora de media de nota #
#
# qual nome do aluno(a): marco
#
# Professor(a),digite a nota de trabalho,prova e participação do aluno
# digite a nota do trabalho: 10
# digite a nota da prova: 10
# digite a nota de participaçao do aluno(a): 10
# marco voce foi aprovado(a)com nota mmaxima 10.0

# %%
#meta estipulada pela empresa para pagar comisssão r$ 3.000,00
metaCliente1 =2500
metacliente2 =3000

#if metaCliente1 >=3000 and metaCliente2 >=3000:
if metaCliente1 >= 3000 or metaCliente2 >= 3000:

  print('PAGAR COMISSÃO')
else:
  print('NÃO PAGAR COMISSÃO, VENDEDOR NÃO ATINGIU AS Meta')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-131-e39f4c8b5b34> in <cell line: 6>()
#       4
#       5 #if metaCliente1 >=3000 and metaCliente2 >=3000:
# ----> 6 if metaCliente1 >= 3000 or metaCliente2 >= 3000:
#       7
#       8   print('PAGAR COMISSÃO')
#
# NameError: name 'metaCliente2' is not defined

# %%
print('seja bem vindo')
print()

nomefuncionario = input('qual nome do funcionario: ')
venda1 = float(input(' valor vendido: '))
venda2 = float(input('valor da comisao; '))

prnint()
# Out:
# seja bem vindo
#
# qual nome do funcionario: ga
#  valor vendido: 27
# valor da comisao; 34
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-cc9d684f0bd6> in <cell line: 8>()
#       6 venda2 = float(input('valor da comisao; '))
#       7
# ----> 8 prnint()
#
# NameError: name 'prnint' is not defined

# %%
print ('#Sistema de calculo de Comissão #')
nossoVendedor = input('digite o nome do vendedor(a): ')
nomeCliente1 = input('digite o nome do primeiro cliente:')
nomeCliente2 = input('digete o nome do segundo cliente: ')
print()

print('$ vamos calcular o faturamento de ',nossoVendedor,'$' )
valorCliente1 = float('faturado para o cliente2:',)
https://colab.research.google.com/drive/13ysktFcFPHAANmyFZKuH3a1NKPKDJcFe?usp=sharingprint()
elif valorCliente1 >= meta and valorCliente2 >= meta
  meta = (valorCliente1 + valorCliente2) * 0.05
  print('parabens,', nomeVendedor, 'voce ganhou de comissão', meta5, 'reais')
if valorCliente1 >= meta or valorCliente2 >= meta
  meta2 =(valorCliente1 + valorCliente2) * 0.025
  print('parabens,',nomeVendedor, 'voce ganhou a comissão',meta2,'reias')
  elseprint('INFELISMENTE VOCE NAO ATINGIU A META E SERA DESLIGADO")
# Out:
#   File "<ipython-input-158-b9aa53c958db>", line 10
#     elif valorCliente1 >= meta and valorCliente2 >= meta
#     ^
# SyntaxError: invalid syntax
